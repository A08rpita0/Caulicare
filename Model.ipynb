# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 4000
CHANNELS=3
EPOCHS=100

# %%
IMAGE_SIZE = 256  # Resize to 224x224 (commonly used for CNNs like ResNet, VGG, etc.)
BATCH_SIZE = 32   # Example batch size

dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Original Dataset",
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),  # Resizing images
    batch_size=BATCH_SIZE
)
# Out:
# Found 656 files belonging to 4 classes.

# %%
class_names=dataset.class_names
class_names
# Out:
# ['Bacterial spot rot', 'Black Rot', 'Downy Mildew', 'No disease']

# %%
plt.figure(figsize=(10,10))
for image_batch,labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
    for i in range(12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")
# Out:
# (32, 256, 256, 3)
# [1 1 1 0 1 3 0 2 0 0 3 2 3 0 0 2 0 1 0 3 0 3 2 2 2 2 0 3 3 1 3 1]

# %%
import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory

# Parameters
IMAGE_SIZE = 256
BATCH_SIZE = 32

# Load full dataset
dataset = image_dataset_from_directory(
    "Original Dataset",
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)

# Calculate dataset sizes
dataset_size = len(dataset)
train_size = int(0.8 * dataset_size)
val_size = int(0.1 * dataset_size)
test_size = dataset_size - train_size - val_size

# Split dataset
train_dataset = dataset.take(train_size)
remaining_dataset = dataset.skip(train_size)
validation_dataset = remaining_dataset.take(val_size)
test_dataset = remaining_dataset.skip(val_size)

print(f"Training size: {train_size}")
print(f"Validation size: {val_size}")
print(f"Test size: {test_size}")
# Out:
# Found 656 files belonging to 4 classes.
# Training size: 16
# Validation size: 2
# Test size: 3

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    # Ensure splits add up to 1
    assert (train_split + val_split + test_split) == 1, "Splits must sum to 1"
    
    # Shuffle dataset if needed
    if shuffle:
        ds = ds.shuffle(shuffle_size, reshuffle_each_iteration=False)

    # Calculate the number of elements for each split
    ds_size = len(ds)
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    test_size = ds_size - train_size - val_size

    # Create partitions
    train_ds = ds.take(train_size)
    remaining_ds = ds.skip(train_size)
    val_ds = remaining_ds.take(val_size)
    test_ds = remaining_ds.skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds,val_ds,test_ds=get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 16

# %%
len(val_ds)
# Out:
# 2

# %%
len(test_ds)
# Out:
# 3

# %%
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds=test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
for image_batch,labels_batch in dataset.take(1):
    print(image_batch[0].numpy()/255)
# Out:
# [[[0.58713233 0.658701   0.48125   ]
#   [0.43553922 0.44828433 0.36583945]
#   [0.48276654 0.51095283 0.4694087 ]
#   ...
#   [0.53186274 0.66519606 0.6691176 ]
#   [0.71896446 0.8204044  0.80893075]
#   [0.5135263  0.64612436 0.62026656]]
#
#  [[0.6089767  0.7079963  0.56902575]
#   [0.5251225  0.53664213 0.48088235]
#   [0.34672183 0.33103552 0.2839767 ]
#   ...
#   [0.6319087  0.76524204 0.7691636 ]
#   [0.6006434  0.7378983  0.7467218 ]
#   [0.69015014 0.808655   0.8103707 ]]
#
#  [[0.5778799  0.65621936 0.5582261 ]
#   [0.4458946  0.501011   0.39906555]
#   [0.428845   0.42159927 0.36095282]
#   ...
#   [0.57598037 0.7014706  0.752451  ]
#   [0.60687804 0.7245251  0.7558977 ]
#   [0.59512866 0.7285846  0.7366728 ]]
#
#  ...
#
#  [[0.6397059  0.7882353  0.77009803]
#   [0.6349112  0.77608764 0.7682445 ]
#   [0.712454   0.78745407 0.77961093]
#   ...
#   [0.6023131  0.7003523  0.68466604]
#   [0.5869332  0.688894   0.67712927]
#   [0.6078585  0.7009957  0.6774663 ]]
#
#  [[0.68325675 0.80580574 0.79551166]
#   [0.64008886 0.7812653  0.7734222 ]
#   [0.71677387 0.79765624 0.7888327 ]
#   ...
#   [0.6271753  0.7252145  0.7095282 ]
#   [0.57303923 0.675      0.6632353 ]
#   [0.63863355 0.7317708  0.7082414 ]]
#
#  [[0.6573989  0.7884191  0.7806832 ]
#   [0.64117646 0.77843136 0.7627451 ]
#   [0.6479473  0.76951593 0.7459865 ]
#   ...
#   [0.62075675 0.71879596 0.7031097 ]
#   [0.6046569  0.70661765 0.69485295]
#   [0.6580576  0.7467831  0.7276654 ]]]

# %%
import tensorflow as tf
from tensorflow.keras import layers

IMAGE_SIZE = 256  # Example image size (height and width)

# Define resize and rescale preprocessing layer
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),  # Resize images to desired size
    layers.Rescaling(1.0 / 255)              # Rescale pixel values to [0, 1]
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2)
])

# %%
input_shape = (BATCH_SIZE,IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes=4
model = models.Sequential([
    resize_and_rescale,  # Preprocessing layer for resizing and rescaling
    data_augmentation,   # Data augmentation layer
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])
model.build(input_shape=input_shape)
# Out:
# C:\Users\Arpita Khobragade\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (32, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (32, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (32, 254, 254, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (32, 127, 127, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (32, 125, 125, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (32, 62, 62, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (32, 60, 60, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (32, 30, 30, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (32, 28, 28, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (32, 14, 14, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (32, 12, 12, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (32, 6, 6, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (32, 4, 4, 64)         │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (32, 2, 2, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (32, 256)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (32, 64)               │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (32, 4)                │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 183,812 (718.02 KB)
#  Trainable params: 183,812 (718.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,            # Training dataset
    validation_data=val_ds,  # Validation dataset
    verbose=1,           # Verbosity mode (1: progress bar)
    epochs=EPOCHS        # Number of epochs
)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 64s 3s/step - accuracy: 0.3536 - loss: 1.3706 - val_accuracy: 0.4219 - val_loss: 1.2734
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.2889 - loss: 1.3445 - val_accuracy: 0.2031 - val_loss: 1.2989
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 984ms/step - accuracy: 0.3403 - loss: 1.2985 - val_accuracy: 0.5312 - val_loss: 1.2105
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.3852 - loss: 1.2383 - val_accuracy: 0.5156 - val_loss: 1.1918
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.3743 - loss: 1.2819 - val_accuracy: 0.3750 - val_loss: 1.1627
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.4402 - loss: 1.2238 - val_accuracy: 0.4375 - val_loss: 1.1731
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 992ms/step - accuracy: 0.5223 - loss: 1.1040 - val_accuracy: 0.6094 - val_loss: 1.1226
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.6280 - loss: 0.9703 - val_accuracy: 0.5938 - val_loss: 0.9779
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.5981 - loss: 0.8896 - val_accuracy: 0.5625 - val_loss: 1.0402
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.6634 - loss: 0.7891 - val_accuracy: 0.6406 - val_loss: 0.7285
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.6165 - loss: 0.8508 - val_accuracy: 0.7500 - val_loss: 0.5807
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 961ms/step - accuracy: 0.7330 - loss: 0.6217 - val_accuracy: 0.8594 - val_loss: 0.5434
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 965ms/step - accuracy: 0.7300 - loss: 0.6378 - val_accuracy: 0.5938 - val_loss: 0.9444
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 978ms/step - accuracy: 0.7368 - loss: 0.6137 - val_accuracy: 0.7500 - val_loss: 0.6275
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.7855 - loss: 0.5695 - val_accuracy: 0.9062 - val_loss: 0.4107
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.7477 - loss: 0.6376 - val_accuracy: 0.7344 - val_loss: 0.6161
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.8259 - loss: 0.4870 - val_accuracy: 0.8906 - val_loss: 0.2394
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.7999 - loss: 0.5361 - val_accuracy: 0.5625 - val_loss: 0.7817
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.8445 - loss: 0.4119 - val_accuracy: 0.9219 - val_loss: 0.2605
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.8276 - loss: 0.4248 - val_accuracy: 0.9219 - val_loss: 0.2416
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 998ms/step - accuracy: 0.8341 - loss: 0.4760 - val_accuracy: 0.8594 - val_loss: 0.4980
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 998ms/step - accuracy: 0.7928 - loss: 0.4565 - val_accuracy: 0.9219 - val_loss: 0.2428
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.8945 - loss: 0.2908 - val_accuracy: 0.7031 - val_loss: 0.9262
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 999ms/step - accuracy: 0.8755 - loss: 0.3329 - val_accuracy: 0.8750 - val_loss: 0.3573
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 987ms/step - accuracy: 0.8422 - loss: 0.3551 - val_accuracy: 0.8906 - val_loss: 0.3829
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 974ms/step - accuracy: 0.9417 - loss: 0.2090 - val_accuracy: 0.8125 - val_loss: 0.5061
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 997ms/step - accuracy: 0.9323 - loss: 0.2208 - val_accuracy: 0.9531 - val_loss: 0.1532
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.8893 - loss: 0.2883 - val_accuracy: 0.7812 - val_loss: 0.7139
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 988ms/step - accuracy: 0.8597 - loss: 0.3683 - val_accuracy: 0.8281 - val_loss: 0.4652
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 973ms/step - accuracy: 0.9162 - loss: 0.2334 - val_accuracy: 0.8906 - val_loss: 0.2423
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9216 - loss: 0.2255 - val_accuracy: 0.8906 - val_loss: 0.2649
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 998ms/step - accuracy: 0.8994 - loss: 0.2301 - val_accuracy: 0.7344 - val_loss: 0.7168
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9385 - loss: 0.1897 - val_accuracy: 0.8750 - val_loss: 0.2786
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 997ms/step - accuracy: 0.8920 - loss: 0.2589 - val_accuracy: 0.8125 - val_loss: 0.5357
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 980ms/step - accuracy: 0.9175 - loss: 0.2074 - val_accuracy: 0.8906 - val_loss: 0.3370
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 996ms/step - accuracy: 0.9372 - loss: 0.1548 - val_accuracy: 0.8906 - val_loss: 0.2761
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 983ms/step - accuracy: 0.9445 - loss: 0.1373 - val_accuracy: 0.8594 - val_loss: 0.4021
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 968ms/step - accuracy: 0.9617 - loss: 0.0994 - val_accuracy: 0.8906 - val_loss: 0.2190
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9194 - loss: 0.2176 - val_accuracy: 0.8594 - val_loss: 0.3216
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 987ms/step - accuracy: 0.9564 - loss: 0.1329 - val_accuracy: 0.8125 - val_loss: 0.3983
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 974ms/step - accuracy: 0.9851 - loss: 0.0791 - val_accuracy: 0.9375 - val_loss: 0.1260
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 982ms/step - accuracy: 0.9894 - loss: 0.0502 - val_accuracy: 0.7969 - val_loss: 0.5350
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 975ms/step - accuracy: 0.9744 - loss: 0.0856 - val_accuracy: 0.7656 - val_loss: 0.5546
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 956ms/step - accuracy: 0.9670 - loss: 0.1022 - val_accuracy: 0.9531 - val_loss: 0.0821
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 941ms/step - accuracy: 0.9169 - loss: 0.2728 - val_accuracy: 0.8750 - val_loss: 0.3097
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 979ms/step - accuracy: 0.9390 - loss: 0.1739 - val_accuracy: 0.8750 - val_loss: 0.3359
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 971ms/step - accuracy: 0.9810 - loss: 0.1226 - val_accuracy: 0.7812 - val_loss: 0.7798
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 980ms/step - accuracy: 0.9505 - loss: 0.1755 - val_accuracy: 0.8906 - val_loss: 0.3575
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9697 - loss: 0.0802 - val_accuracy: 0.9219 - val_loss: 0.2607
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9774 - loss: 0.0719 - val_accuracy: 0.9062 - val_loss: 0.3088
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 967ms/step - accuracy: 0.9736 - loss: 0.0700 - val_accuracy: 0.9375 - val_loss: 0.3158
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 969ms/step - accuracy: 0.9809 - loss: 0.0585 - val_accuracy: 0.9531 - val_loss: 0.1107
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 968ms/step - accuracy: 0.9860 - loss: 0.0358 - val_accuracy: 0.9531 - val_loss: 0.0861
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 965ms/step - accuracy: 0.9739 - loss: 0.0823 - val_accuracy: 1.0000 - val_loss: 0.0227
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9842 - loss: 0.0423 - val_accuracy: 0.9531 - val_loss: 0.1047
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 968ms/step - accuracy: 0.9734 - loss: 0.0724 - val_accuracy: 0.8594 - val_loss: 0.4411
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 947ms/step - accuracy: 0.9837 - loss: 0.0443 - val_accuracy: 0.9375 - val_loss: 0.2023
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 969ms/step - accuracy: 0.9925 - loss: 0.0226 - val_accuracy: 0.9688 - val_loss: 0.1376
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9916 - loss: 0.0289 - val_accuracy: 0.9062 - val_loss: 0.3529
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9783 - loss: 0.0499 - val_accuracy: 0.8906 - val_loss: 0.3179
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 991ms/step - accuracy: 0.9922 - loss: 0.0322 - val_accuracy: 0.9844 - val_loss: 0.0416
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9760 - loss: 0.0547 - val_accuracy: 1.0000 - val_loss: 0.0463
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9959 - loss: 0.0197 - val_accuracy: 0.9219 - val_loss: 0.2793
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9929 - loss: 0.0327 - val_accuracy: 0.8594 - val_loss: 0.3542
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9992 - loss: 0.0127 - val_accuracy: 0.9375 - val_loss: 0.1165
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9976 - loss: 0.0102 - val_accuracy: 0.9062 - val_loss: 0.1995
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9952 - loss: 0.0159 - val_accuracy: 0.9688 - val_loss: 0.1082
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9908 - loss: 0.0193 - val_accuracy: 0.8594 - val_loss: 0.4245
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9978 - loss: 0.0126 - val_accuracy: 0.9688 - val_loss: 0.0469
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9936 - loss: 0.0136 - val_accuracy: 0.8906 - val_loss: 0.3425
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9219 - val_loss: 0.1603
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9954 - loss: 0.0159 - val_accuracy: 0.7188 - val_loss: 1.4770
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9668 - loss: 0.0819 - val_accuracy: 0.9062 - val_loss: 0.6745
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 999ms/step - accuracy: 0.9256 - loss: 0.1973 - val_accuracy: 0.9531 - val_loss: 0.1355
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 991ms/step - accuracy: 0.9453 - loss: 0.1331 - val_accuracy: 0.8750 - val_loss: 0.3888
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9571 - loss: 0.1534 - val_accuracy: 0.8594 - val_loss: 0.4088
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9664 - loss: 0.1084 - val_accuracy: 0.7344 - val_loss: 0.8311
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9449 - loss: 0.1412 - val_accuracy: 0.7812 - val_loss: 0.5737
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9810 - loss: 0.0494 - val_accuracy: 0.8750 - val_loss: 0.3649
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9834 - loss: 0.0492 - val_accuracy: 0.9375 - val_loss: 0.2140
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9966 - loss: 0.0153 - val_accuracy: 0.9531 - val_loss: 0.1036
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9867 - loss: 0.0286 - val_accuracy: 0.9844 - val_loss: 0.0293
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9935 - loss: 0.0169 - val_accuracy: 0.8906 - val_loss: 0.2871
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9995 - loss: 0.0080 - val_accuracy: 0.9688 - val_loss: 0.0752
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9978 - loss: 0.0042 - val_accuracy: 0.9219 - val_loss: 0.2268
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9219 - val_loss: 0.2462
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9531 - val_loss: 0.1379
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9531 - val_loss: 0.1178
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 9.6841e-04 - val_accuracy: 0.9531 - val_loss: 0.1245
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9531 - val_loss: 0.1013
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9531 - val_loss: 0.1095
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.4213e-04 - val_accuracy: 0.9531 - val_loss: 0.1082
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 4.0771e-04 - val_accuracy: 0.9375 - val_loss: 0.1489
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 7.3937e-04 - val_accuracy: 0.9375 - val_loss: 0.1442
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 1.8845e-04 - val_accuracy: 0.9531 - val_loss: 0.1121
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9688 - val_loss: 0.1249
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 5.8350e-04 - val_accuracy: 0.9531 - val_loss: 0.1207
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 1.7014e-04 - val_accuracy: 0.9375 - val_loss: 0.1183
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 3.9049e-04 - val_accuracy: 0.9375 - val_loss: 0.1331
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 984ms/step - accuracy: 1.0000 - loss: 5.1252e-04 - val_accuracy: 0.9375 - val_loss: 0.1378

# %%
scores=model.evaluate(test_ds)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 46s 400ms/step - accuracy: 0.9609 - loss: 0.1464

# %%
scores
# Out:
# [0.10755884647369385, 0.96875]

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
history.history['loss']
# Out:
# [1.3633837699890137,
#  1.3331488370895386,
#  1.2724518775939941,
#  1.2658754587173462,
#  1.297519326210022,
#  1.1782525777816772,
#  1.0640676021575928,
#  0.9915815591812134,
#  0.8924486637115479,
#  0.7911310791969299,
#  0.7776852250099182,
#  0.6616331338882446,
#  0.6326759457588196,
#  0.5955597758293152,
#  0.6292096972465515,
#  0.5825501680374146,
#  0.477337121963501,
#  0.49245336651802063,
#  0.4055953621864319,
#  0.3943517804145813,
#  0.46555402874946594,
#  0.4401620924472809,
#  0.2953035533428192,
#  0.3681630492210388,
#  0.34834787249565125,
#  0.20236852765083313,
#  0.23634953796863556,
#  0.3442324101924896,
#  0.3231213688850403,
#  0.25427982211112976,
#  0.2349015325307846,
#  0.24774232506752014,
#  0.20830751955509186,
#  0.22088372707366943,
#  0.21086546778678894,
#  0.1436273753643036,
#  0.1174064353108406,
#  0.10695959627628326,
#  0.20472830533981323,
#  0.16530176997184753,
#  0.08403874188661575,
#  0.054665129631757736,
#  0.08390309661626816,
#  0.08796192705631256,
#  0.31172677874565125,
#  0.16296452283859253,
#  0.1210709884762764,
#  0.15551237761974335,
#  0.06883858889341354,
#  0.08673064410686493,
#  0.07768206298351288,
#  0.07771892845630646,
#  0.03306368738412857,
#  0.0819077119231224,
#  0.04442794993519783,
#  0.09138094633817673,
#  0.04871352016925812,
#  0.029359927400946617,
#  0.04083690047264099,
#  0.036264654248952866,
#  0.040798742324113846,
#  0.04835392162203789,
#  0.02311086840927601,
#  0.025307634845376015,
#  0.012288217432796955,
#  0.01269353087991476,
#  0.01650225929915905,
#  0.019842153415083885,
#  0.010936765000224113,
#  0.006077534984797239,
#  0.003632477717474103,
#  0.04334119334816933,
#  0.08120986074209213,
#  0.14952726662158966,
#  0.11434157192707062,
#  0.18364837765693665,
#  0.10555912554264069,
#  0.1203143298625946,
#  0.04376320168375969,
#  0.04815485328435898,
#  0.02136174403131008,
#  0.025462176650762558,
#  0.010624834336340427,
#  0.013936718925833702,
#  0.005080435425043106,
#  0.004034031182527542,
#  0.001400844776071608,
#  0.0012151800328865647,
#  0.0007764368783682585,
#  0.001586392754688859,
#  0.0015460805734619498,
#  0.0010432504350319505,
#  0.000629887857940048,
#  0.0007307241321541369,
#  0.00022621739481110126,
#  0.000955066760070622,
#  0.0005305981612764299,
#  0.0002338458871236071,
#  0.0004764532495755702,
#  0.0006962252082303166]

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1,2,1)
plt.plot(range(EPOCHS),acc,label='Training Accuracy')
plt.plot(range(EPOCHS),val_acc,label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.subplot(1,2,2)
plt.plot(range(EPOCHS),loss,label='Training Loss')
plt.plot(range(EPOCHS),val_loss,label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    first_image=images_batch[0].numpy().astype("uint8")
    print("First image to predict")
    plt.imshow(first_image)
    print("Actual Label:",class_names[labels_batch[0].numpy()])
    batch_prediction=model.predict(images_batch)   
    print("Predicted Label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# First image to predict
# Actual Label: Downy Mildew
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 718ms/step
# Predicted Label: Downy Mildew

# %%
def predict(model, img):
    img_array=tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array=tf.expand_dims(img_array,0)

    predictions=model.predict(img_array)
    predicted_class=class_names[np.argmax(predictions[0])]
    confidence=round(100*(np.max(predictions[0])),2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15,15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predicted_class, confidence = predict(model, images[i].numpy())

        actual_class = class_names[labels[i]]
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        plt.axis("off")

# %%
import os

# Now you can use os.listdir
os.listdir("../models")
# Out:
# ['1.keras']

# %%
models_version=1
model.save(f"../models.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os

# List files in the directory
files = os.listdir("../models")

# Filter out files that cannot be converted to integers
model_versions = [int(f.split('.')[0]) for f in files if f.split('.')[0].isdigit()]

# Add 0 to the list if necessary
model_versions.append(0)

# Now, model_versions contains valid integer versions
print(model_versions)
# Out:
# [1, 0]
